# %%
#importing the libraries in the dataset
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Knowing the dataset

# %%
#loading the data
df = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\data.csv")
df
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
#         duration_ms  energy  explicit                      id  \
# 0            158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD
# 1            282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV
# 2            104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM
# 3            180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8
# 4            687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd
# ...             ...     ...       ...                     ...
# 169904       163800  0.4430         1  4KppkflX7I3vJQk7urOJaS
# 169905       167468  0.3850         0  1ehhGlTvjtHo2e4xJFB0SZ
# 169906       180700  0.5390         0  52eycxprLhK3lPcRLbQiVk
# 169907       167308  0.7610         0  3wYOGJYD31sLRmBgCvWxa4
# 169908       214787  0.4280         0  60RFlt48hm0l4Fu0JoccOl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.563000   10    0.1510   -12.428     1
# 1               0.901000    8    0.0763   -28.454     1
# 2               0.000000    5    0.1190   -19.924     0
# 3               0.887000    1    0.1110   -14.734     0
# 4               0.908000   11    0.0980   -16.829     1
# ...                  ...  ...       ...       ...   ...
# 169904          0.000032    1    0.0891    -7.461     1
# 169905          0.031300    8    0.1110   -10.907     1
# 169906          0.002330    7    0.1080    -9.332     1
# 169907          0.000000    1    0.2220    -2.557     1
# 169908          0.000000    0    0.1050    -7.387     1
#
#                                                  name  popularity  \
# 0                         Singende Bataillone 1. Teil           0
# 1            Fantasiestücke, Op. 111: Più tosto lento           0
# 2                      Chapter 1.18 - Zamek kaniowski           0
# 3       Bebamos Juntos - Instrumental (Remasterizado)           0
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61           1
# ...                                               ...         ...
# 169904                  Skechers (feat. Tyga) - Remix          75
# 169905                 Sweeter (feat. Terrace Martin)          64
# 169906                               How Would I Know          70
# 169907                                    I Found You          70
# 169908                          More Hearts Than Mine          65
#
#        release_date  speechiness    tempo  valence  year
# 0              1928       0.0506  118.469   0.7790  1928
# 1              1928       0.0462   83.972   0.0767  1928
# 2              1928       0.9290  107.177   0.8800  1928
# 3        1928-09-25       0.0926  108.003   0.7200  1928
# 4              1928       0.0424   62.149   0.0693  1928
# ...             ...          ...      ...      ...   ...
# 169904   2020-05-15       0.1430  100.012   0.3060  2020
# 169905   2020-06-08       0.0403  128.000   0.2700  2020
# 169906   2020-05-29       0.1050  123.700   0.1530  2020
# 169907   2020-02-28       0.0385  129.916   0.4720  2020
# 169908   2020-03-27       0.0271   80.588   0.3660  2020
#
# [169909 rows x 19 columns]

# %% [markdown]
# ### Display first 5 rows in dataset

# %%
df.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %% [markdown]
# ### Display last 5 rows in dataset

# %%
df.tail()
# Out:
#         acousticness                             artists  danceability  \
# 169904        0.1730              ['DripReport', 'Tyga']         0.875
# 169905        0.0167  ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380               ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714       ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                  ['Ingrid Andress']         0.512
#
#         duration_ms  energy  explicit                      id  \
# 169904       163800   0.443         1  4KppkflX7I3vJQk7urOJaS
# 169905       167468   0.385         0  1ehhGlTvjtHo2e4xJFB0SZ
# 169906       180700   0.539         0  52eycxprLhK3lPcRLbQiVk
# 169907       167308   0.761         0  3wYOGJYD31sLRmBgCvWxa4
# 169908       214787   0.428         0  60RFlt48hm0l4Fu0JoccOl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 169904          0.000032    1    0.0891    -7.461     1
# 169905          0.031300    8    0.1110   -10.907     1
# 169906          0.002330    7    0.1080    -9.332     1
# 169907          0.000000    1    0.2220    -2.557     1
# 169908          0.000000    0    0.1050    -7.387     1
#
#                                   name  popularity release_date  speechiness  \
# 169904   Skechers (feat. Tyga) - Remix          75   2020-05-15       0.1430
# 169905  Sweeter (feat. Terrace Martin)          64   2020-06-08       0.0403
# 169906                How Would I Know          70   2020-05-29       0.1050
# 169907                     I Found You          70   2020-02-28       0.0385
# 169908           More Hearts Than Mine          65   2020-03-27       0.0271
#
#           tempo  valence  year
# 169904  100.012    0.306  2020
# 169905  128.000    0.270  2020
# 169906  123.700    0.153  2020
# 169907  129.916    0.472  2020
# 169908   80.588    0.366  2020

# %% [markdown]
# ## To count, mean, standard deviation, minimum and maximum values |

# %%
df.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  169909.000000  169909.000000  1.699090e+05  169909.000000
# mean        0.493214       0.538150  2.314062e+05       0.488593
# std         0.376627       0.175346  1.213219e+05       0.267390
# min         0.000000       0.000000  5.108000e+03       0.000000
# 25%         0.094500       0.417000  1.710400e+05       0.263000
# 50%         0.492000       0.548000  2.086000e+05       0.481000
# 75%         0.888000       0.667000  2.629600e+05       0.710000
# max         0.996000       0.988000  5.403500e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  169909.000000     169909.000000  169909.000000  169909.000000
# mean        0.084863          0.161937       5.200519       0.206690
# std         0.278679          0.309329       3.515257       0.176796
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.000000          0.000000       2.000000       0.098400
# 50%         0.000000          0.000204       5.000000       0.135000
# 75%         0.000000          0.086800       8.000000       0.263000
# max         1.000000          1.000000      11.000000       1.000000
#
#             loudness           mode     popularity    speechiness  \
# count  169909.000000  169909.000000  169909.000000  169909.000000
# mean      -11.370289       0.708556      31.556610       0.094058
# std         5.666765       0.454429      21.582614       0.149937
# min       -60.000000       0.000000       0.000000       0.000000
# 25%       -14.470000       0.000000      12.000000       0.034900
# 50%       -10.474000       1.000000      33.000000       0.045000
# 75%        -7.118000       1.000000      48.000000       0.075400
# max         3.855000       1.000000     100.000000       0.969000
#
#                tempo        valence           year
# count  169909.000000  169909.000000  169909.000000
# mean      116.948017       0.532095    1977.223231
# std        30.726937       0.262408      25.593168
# min         0.000000       0.000000    1921.000000
# 25%        93.516000       0.322000    1957.000000
# 50%       114.778000       0.544000    1978.000000
# 75%       135.712000       0.749000    1999.000000
# max       244.091000       1.000000    2020.000000

# %% [markdown]
# ## Information about the coloumns in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169909 entries, 0 to 169908
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      169909 non-null  float64
#  1   artists           169909 non-null  object
#  2   danceability      169909 non-null  float64
#  3   duration_ms       169909 non-null  int64
#  4   energy            169909 non-null  float64
#  5   explicit          169909 non-null  int64
#  6   id                169909 non-null  object
#  7   instrumentalness  169909 non-null  float64
#  8   key               169909 non-null  int64
#  9   liveness          169909 non-null  float64
#  10  loudness          169909 non-null  float64
#  11  mode              169909 non-null  int64
#  12  name              169909 non-null  object
#  13  popularity        169909 non-null  int64
#  14  release_date      169909 non-null  object
#  15  speechiness       169909 non-null  float64
#  16  tempo             169909 non-null  float64
#  17  valence           169909 non-null  float64
#  18  year              169909 non-null  int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 24.6+ MB

# %% [markdown]
# ## Data Cleaning
# ## Checking for null values

# %%
df.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %% [markdown]
# ####

# %% [markdown]
# #### from that we can infer that there are no null values in any of our columns of the dataset. Hennce, the process of dealing with null values or replacing with inferential statistics cannot be done(as there are no null mvalues in dataset)

# %% [markdown]
# ### finding total number of rows and columns from the data set using shape

# %%
df.shape
# Out:
# (169909, 19)

# %% [markdown]
# ### total number of items in dataset

# %%
df.size
# Out:
# 3228271

# %% [markdown]
# ### which types are there in each column in the dataset

# %%
df.dtypes
# Out:
# acousticness        float64
# artists              object
# danceability        float64
# duration_ms           int64
# energy              float64
# explicit              int64
# id                   object
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# name                 object
# popularity            int64
# release_date         object
# speechiness         float64
# tempo               float64
# valence             float64
# year                  int64
# dtype: object

# %%
df.nunique()
# Out:
# acousticness          4714
# artists              33375
# danceability          1232
# duration_ms          50212
# energy                2332
# explicit                 2
# id                  169909
# instrumentalness      5401
# key                     12
# liveness              1741
# loudness             25313
# mode                     2
# name                132940
# popularity             100
# release_date         10882
# speechiness           1628
# tempo                84548
# valence               1739
# year                   100
# dtype: int64

# %% [markdown]
# ### what are duplicate values and how to check duplicate values ?

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 169904    False
# 169905    False
# 169906    False
# 169907    False
# 169908    False
# Length: 169909, dtype: bool

# %% [markdown]
# #### A duplicate values is one in which all values at least one row are identical to all of the values in another row, how can duplicate values be removed or how to check only non-duplicate value ?

# %%
df.drop_duplicates(subset=['key'])
# Out:
#     acousticness                                      artists  danceability  \
# 0          0.995                          ['Carl Woitschach']         0.708
# 1          0.994     ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2          0.604                      ['Seweryn Goszczyński']         0.749
# 3          0.995                         ['Francisco Canaro']         0.781
# 4          0.990     ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# 5          0.995   ['Felix Mendelssohn', 'Vladimir Horowitz']         0.424
# 8          0.995               ['Francisco Canaro', 'Charlo']         0.683
# 12         0.990       ['Samuel Barber', 'Vladimir Horowitz']         0.359
# 16         0.996  ['Alexander Scriabin', 'Vladimir Horowitz']         0.319
# 29         0.686                      ['Seweryn Goszczyński']         0.715
# 49         0.993         ['Franz Liszt', 'Vladimir Horowitz']         0.303
# 64         0.989     ['Robert Schumann', 'Vladimir Horowitz']         0.368
#
#     duration_ms  energy  explicit                      id  instrumentalness  \
# 0        158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1        282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2        104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3        180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4        687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
# 5        352600  0.1200         0  6NxAf7M8DNHOBTmEd3JSO5             0.911
# 8        162493  0.2070         0  6OaJ8Bh7lsBeYoBmwmo2nh             0.206
# 12       338333  0.0435         0  6QgdUySTRGVkNo3KwbHpK3             0.899
# 16       326067  0.1550         0  6T0mZB7p3qzOifdXZ3Su9P             0.917
# 29       102200  0.2200         0  6XD6qJykJ91uC9AYb84ZeY             0.000
# 49       491333  0.2260         0  6jm4s7lONpJRXumjV6WH23             0.826
# 64       163800  0.1240         0  6p8Q6LG6m1kxAzTbUyIWN3             0.892
#
#     key  liveness  loudness  mode  \
# 0    10    0.1510   -12.428     1
# 1     8    0.0763   -28.454     1
# 2     5    0.1190   -19.924     0
# 3     1    0.1110   -14.734     0
# 4    11    0.0980   -16.829     1
# 5     6    0.0915   -19.242     0
# 8     9    0.3370    -9.801     0
# 12    7    0.1090   -20.858     1
# 16    4    0.1260   -18.728     1
# 29    2    0.2060   -19.788     1
# 49    3    0.1190   -21.483     1
# 64    0    0.1050   -21.742     0
#
#                                                  name  popularity  \
# 0                         Singende Bataillone 1. Teil           0
# 1            Fantasiestücke, Op. 111: Più tosto lento           0
# 2                      Chapter 1.18 - Zamek kaniowski           0
# 3       Bebamos Juntos - Instrumental (Remasterizado)           0
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61           1
# 5                         Scherzo a capriccio: Presto           0
# 8                    Moneda Corriente - Remasterizado           0
# 12  Piano Sonata in E-Flat Minor, Op. 26: III. Ada...           0
# 16  Sonata No. 3, Op. 23 in F-Sharp Minor: IV. Pre...           0
# 29                     Chapter 4.12 - Zamek kaniowski           0
# 49  Danse macabre, S. 555 (after Camille Saint-Saens)           0
# 64                      Humoreske, Op. 20: Intermezzo           0
#
#    release_date  speechiness    tempo  valence  year
# 0          1928       0.0506  118.469   0.7790  1928
# 1          1928       0.0462   83.972   0.0767  1928
# 2          1928       0.9290  107.177   0.8800  1928
# 3    1928-09-25       0.0926  108.003   0.7200  1928
# 4          1928       0.0424   62.149   0.0693  1928
# 5          1928       0.0593   63.521   0.2660  1928
# 8    1928-10-03       0.1270  119.833   0.4930  1928
# 12         1928       0.0424   96.645   0.0420  1928
# 16         1928       0.0360   66.947   0.0488  1928
# 29         1928       0.9480  113.214   0.5450  1928
# 49         1928       0.0444   67.013   0.1460  1928
# 64         1928       0.0371  128.418   0.2660  1928

# %% [markdown]
# ## Null_Values in dataset

# %%
df.isnull()
# Out:
#         acousticness  artists  danceability  duration_ms  energy  explicit  \
# 0              False    False         False        False   False     False
# 1              False    False         False        False   False     False
# 2              False    False         False        False   False     False
# 3              False    False         False        False   False     False
# 4              False    False         False        False   False     False
# ...              ...      ...           ...          ...     ...       ...
# 169904         False    False         False        False   False     False
# 169905         False    False         False        False   False     False
# 169906         False    False         False        False   False     False
# 169907         False    False         False        False   False     False
# 169908         False    False         False        False   False     False
#
#            id  instrumentalness    key  liveness  loudness   mode   name  \
# 0       False             False  False     False     False  False  False
# 1       False             False  False     False     False  False  False
# 2       False             False  False     False     False  False  False
# 3       False             False  False     False     False  False  False
# 4       False             False  False     False     False  False  False
# ...       ...               ...    ...       ...       ...    ...    ...
# 169904  False             False  False     False     False  False  False
# 169905  False             False  False     False     False  False  False
# 169906  False             False  False     False     False  False  False
# 169907  False             False  False     False     False  False  False
# 169908  False             False  False     False     False  False  False
#
#         popularity  release_date  speechiness  tempo  valence   year
# 0            False         False        False  False    False  False
# 1            False         False        False  False    False  False
# 2            False         False        False  False    False  False
# 3            False         False        False  False    False  False
# 4            False         False        False  False    False  False
# ...            ...           ...          ...    ...      ...    ...
# 169904       False         False        False  False    False  False
# 169905       False         False        False  False    False  False
# 169906       False         False        False  False    False  False
# 169907       False         False        False  False    False  False
# 169908       False         False        False  False    False  False
#
# [169909 rows x 19 columns]

# %%
df["mode"].fillna("No mode", inplace = True) 
    
df.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
#just replace all the missing data with the mode of the column in dataset 
mode = df['tempo'].mode().values[0]
df['tempo']= df['tempo'].replace(np.nan, mode)
  
df.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %% [markdown]
# # Handling Outliers

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.boxplot(df['tempo'])
# Out:
# <AxesSubplot:xlabel='tempo'>

# %%
cols = 5
rows = 5
num_cols = df.select_dtypes(exclude='object').columns
fig = plt.figure(figsize= (20,10))
for i, col in enumerate(num_cols):
    
    ax=fig.add_subplot( rows, cols, i+1)
    
    sns.boxplot(x=df[col], ax=ax)
    
fig.tight_layout()  
plt.show()

#Here, the numerical columns must be selected in order to visualise the histplot. For that, Datatypes like 'Object'
#(i.e, categorical) need to be excluded from the process of importing.
# Note: 'plt.show()' is a mandatory command in order to print the executed process.

# %%
print(np.where(df['tempo']>200))
# Out:
# (array([   114,    146,    280, ..., 169446, 169547, 169817], dtype=int64),)

# %%
#scatter plot
fig, ax = plt.subplots(figsize = (8,10))
ax.scatter(df['tempo'], df['loudness'])
 

ax.set_xlabel("x_axis")

ax.set_ylabel("y_axis")
plt.show()

# %%
print(np.where((df['tempo']>200) & (df['loudness']>-20)))
# Out:
# (array([   114,    146,    280, ..., 169406, 169547, 169817], dtype=int64),)

# %%
#IQR
Q1 = np.percentile(df['tempo'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['tempo'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
print(IQR)
print(Q3)
print(Q1)
# Out:
# 42.19600000000001
# 135.71200000000002
# 93.516

# %%
upper = df['tempo'] >= (Q3+1.5*IQR)
 
print("Upper bound:",upper)
print(np.where(upper))
 
lower = df['tempo'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))
# Out:
# Upper bound: 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 169904    False
# 169905    False
# 169906    False
# 169907    False
# 169908    False
# Name: tempo, Length: 169909, dtype: bool
# (array([   114,    146,    280, ..., 169446, 169547, 169817], dtype=int64),)
# Lower bound: 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 169904    False
# 169905    False
# 169906    False
# 169907    False
# 169908    False
# Name: tempo, Length: 169909, dtype: bool
# (array([  1269,   2721,   3387,   6930,   7411,   7792,   8834,   9389,
#         15605,  15787,  15864,  15870,  16054,  16084,  23443,  23862,
#         23900,  26077,  26491,  26775,  30921,  31147,  31701,  31709,
#         31870,  31894,  32001,  33408,  33616,  39571,  39706,  39774,
#         39807,  41240,  41981,  43098,  46958,  47326,  47417,  47525,
#         48566,  48911,  49178,  51299,  55438,  56699,  56764,  56768,
#         61074,  61972,  62254,  62687,  62887,  63131,  63451,  64133,
#         64593,  65061,  69985,  70154,  70162,  77648,  77738,  79679,
#         82409,  87299,  87456,  87651,  87652,  87653,  88137,  88224,
#         89197,  89656,  89673,  89884,  90678,  94905,  96714,  96970,
#         97314,  97419,  97541,  97840,  98405,  99092,  99703, 100219,
#        100483, 106685, 106728, 106802, 107149, 108249, 108452, 108757,
#        109137, 109321, 110587, 111528, 116201, 116385, 116623, 117645,
#        118904, 118930, 119221, 121539, 125097, 125716, 125820, 125835,
#        125852, 125880, 125909, 127144, 127932, 128458, 135039, 135129,
#        135206, 135281, 136936, 137188, 137617, 143826, 143939, 144175,
#        145539, 145844, 145929, 153404, 153722, 154221, 154560, 160792,
#        160976, 161177, 161194, 161305, 161443, 161927, 162730, 164201,
#        169522, 169743, 169770], dtype=int64),)

# %% [markdown]
# # Univariate Analysis
# ## Categorical columns
# #### counting the values in dataset variable

# %%
df['artists'].value_counts()
# Out:
# ['Эрнест Хемингуэй']                                  1215
# ['Francisco Canaro']                                   938
# ['Эрих Мария Ремарк']                                  781
# ['Ignacio Corsini']                                    620
# ['Frank Sinatra']                                      592
#                                                       ...
# ['Don Omar', 'Zion & Lennox']                            1
# ['Sia', 'Alan Walker']                                   1
# ['Excision', 'Space Laces']                              1
# ['A$AP Mob', 'A$AP Rocky', 'A$AP Twelvyy', 'KEY!']       1
# ['Cash Cash', 'Andy Grammer']                            1
# Name: artists, Length: 33375, dtype: int64

# %%
df['name'].value_counts()
# Out:
# Summertime                                              62
# Overture                                                43
# Home                                                    40
# Stay                                                    34
# You                                                     33
#                                                         ..
# Are We Going Down                                        1
# The Century of the Common Man                            1
# El Noveno Mandamiento - Instrumental (Remasterizado)     1
# É Ôro Só (Ponto de Exu)                                  1
# How Would I Know                                         1
# Name: name, Length: 132940, dtype: int64

# %% [markdown]
# ### Bar Chart

# %%
#The bar plot is a univariate data visualization plot on a two-dimensional axis. One axis is the category axis indicating the category, while the second axis is the value axis that shows the numeric value of that category, indicated by the length of the bar.
df['key'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#countplot
sns.countplot(df['key'])
# Out:
# <AxesSubplot:xlabel='key', ylabel='count'>

# %% [markdown]
# # Pie Chart
# A pie chart is the most common way used to visualize the numerical proportion occupied by each of the categories.

# %%
df['key'].value_counts().plot(kind="pie", autopct="%.0f%%")
plt.show()

# %% [markdown]
# ### continuous columns
#
# #### Histogram
# A histogram is a value distribution plot of numerical columns. It basically creates bins in various ranges in values and plots it where we can visualize how values are distributed. We can have a look where more values lie like in positive, negative, or at the center(mean).

# %%
plt.hist(df['key'], bins=10)
plt.show()

# %% [markdown]
# ### Dist Plot
# Distplot is also known as the second Histogram because it is a slight improvement version of the Histogram. Distplot gives us a KDE(Kernel Density Estimation) over histogram which explains PDF(Probability Density Function) which means what is the probability of each value occurring in this column.

# %%
sns.distplot(df['key'])
plt.show()

# %% [markdown]
# ## Bivariate Analysis
#
# ### Categorical vs. Numerical columns
#
# #### Box plot
# Boxplot is a very interesting plot that basically plots a 5 number summary.

# %%
sns.boxplot(df['duration_ms'])
# Out:
# <AxesSubplot:xlabel='duration_ms'>

# %%
print(np.where(df['duration_ms']>0.5))
# Out:
# (array([     0,      1,      2, ..., 169906, 169907, 169908], dtype=int64),)

# %% [markdown]
# ### Minimum and Maximum of IQR
# These are not minimum and maximum values, rather they describe the lower and upper boundary of standard deviation which is calculated using Interquartile range(IQR).

# %%
Q1 = np.percentile(df['key'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['key'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
print(IQR)
print(Q3)
print(Q1)
# Out:
# 6.0
# 8.0
# 2.0

# %%
upper = df['key'] >= (Q3+1.5*IQR)
 
print("Upper bound:",upper)
print(np.where(upper))
 
lower = df['key'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))
# Out:
# Upper bound: 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 169904    False
# 169905    False
# 169906    False
# 169907    False
# 169908    False
# Name: key, Length: 169909, dtype: bool
# (array([], dtype=int64),)
# Lower bound: 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 169904    False
# 169905    False
# 169906    False
# 169907    False
# 169908    False
# Name: key, Length: 169909, dtype: bool
# (array([], dtype=int64),)

# %% [markdown]
# ### Bar Plot

# %%
#Bar plot is a simple plot which we can use to plot categorical variable on the x-axis and numerical variable on y-axis and explore the relationship between both variables.
sns.barplot(df['key'],df['mode'])
plt.show()
